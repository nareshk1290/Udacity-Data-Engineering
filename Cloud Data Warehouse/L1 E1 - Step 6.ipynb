# %% [markdown]
# # STEP 6: Repeat the computation from the facts & dimension table
#
# Note: You will not have to write any code in this notebook. It's purely to illustrate the performance difference between Star and 3NF schemas.
#
# Start by running the code in the cell below to connect to the database.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-data.sql
# Out:
# psql:Data/pagila-data.sql:23: ERROR:  relation "actor" does not exist
# psql:Data/pagila-data.sql:224: invalid command \.
# psql:Data/pagila-data.sql:231: ERROR:  syntax error at or near "1"
# LINE 1: 1 PENELOPE GUINESS 2017-02-15 09:34:33
#         ^
# psql:Data/pagila-data.sql:341: invalid command \.
# psql:Data/pagila-data.sql:348: ERROR:  syntax error at or near "1"
# LINE 1: 1 Afghanistan 2017-02-15 09:44:00
#         ^
# psql:Data/pagila-data.sql:949: invalid command \.
# psql:Data/pagila-data.sql:956: ERROR:  syntax error at or near "1"
# LINE 1: 1 A Corua (La Corua) 87 2017-02-15 09:45:25
#         ^
# psql:Data/pagila-data.sql:957: invalid command \N
# psql:Data/pagila-data.sql:958: invalid command \N
# psql:Data/pagila-data.sql:959: invalid command \N
# psql:Data/pagila-data.sql:960: invalid command \N
# psql:Data/pagila-data.sql:1560: invalid command \.
# psql:Data/pagila-data.sql:1567: ERROR:  syntax error at or near "1"
# LINE 1: 1 47 MySakila Drive
#         ^
# psql:Data/pagila-data.sql:1584: invalid command \.
# psql:Data/pagila-data.sql:1591: ERROR:  syntax error at or near "1"
# LINE 1: 1 Action 2017-02-15 09:46:27
#         ^
# psql:Data/pagila-data.sql:1594: invalid command \.
# psql:Data/pagila-data.sql:1601: ERROR:  syntax error at or near "1"
# LINE 1: 1 1 1 2017-02-15 09:57:12
#         ^
# psql:Data/pagila-data.sql:2201: invalid command \.
# psql:Data/pagila-data.sql:2208: ERROR:  syntax error at or near "1"
# LINE 1: 1 1 MARY SMITH MARY.SMITH@sakilacustomer.org 5 t 2017-02-14 ...
#         ^
# psql:Data/pagila-data.sql:2215: invalid command \.
# psql:Data/pagila-data.sql:2222: ERROR:  syntax error at or near "1"
# LINE 1: 1 English              2017-02-15 10:02:19
#         ^
# psql:Data/pagila-data.sql:2223: invalid command \N
# psql:Data/pagila-data.sql:2224: invalid command \N
# psql:Data/pagila-data.sql:2225: invalid command \N
# psql:Data/pagila-data.sql:2226: invalid command \N
# psql:Data/pagila-data.sql:2227: invalid command \N
# psql:Data/pagila-data.sql:2228: invalid command \N
# psql:Data/pagila-data.sql:2229: invalid command \N
# psql:Data/pagila-data.sql:2230: invalid command \N
# psql:Data/pagila-data.sql:2231: invalid command \N
# psql:Data/pagila-data.sql:2232: invalid command \N
# psql:Data/pagila-data.sql:2233: invalid command \N
# psql:Data/pagila-data.sql:2234: invalid command \N
# psql:Data/pagila-data.sql:2235: invalid command \N
# psql:Data/pagila-data.sql:2236: invalid command \N
# psql:Data/pagila-data.sql:2237: invalid command \N
# psql:Data/pagila-data.sql:2238: invalid command \N
# psql:Data/pagila-data.sql:2239: invalid command \N
# psql:Data/pagila-data.sql:2240: invalid command \N
# psql:Data/pagila-data.sql:2241: invalid command \N
# psql:Data/pagila-data.sql:2242: invalid command \N
# psql:Data/pagila-data.sql:2243: invalid command \N
# psql:Data/pagila-data.sql:2244: invalid command \N
# psql:Data/pagila-data.sql:2245: invalid command \N
# psql:Data/pagila-data.sql:2246: invalid command \N
# psql:Data/pagila-data.sql:2247: invalid command \N
# psql:Data/pagila-data.sql:2248: invalid command \N
# psql:Data/pagila-data.sql:2249: invalid command \N
# psql:Data/pagila-data.sql:2250: invalid command \N
# psql:Data/pagila-data.sql:2251: invalid command \N
# psql:Data/pagila-data.sql:2252: invalid command \N
# psql:Data/pagila-data.sql:2253: invalid command \N
# psql:Data/pagila-data.sql:2254: invalid command \N
# psql:Data/pagila-data.sql:2255: invalid command \N
# psql:Data/pagila-data.sql:2256: invalid command \N
# psql:Data/pagila-data.sql:2257: invalid command \N
# psql:Data/pagila-data.sql:2258: invalid command \N
# psql:Data/pagila-data.sql:2259: invalid command \N
# psql:Data/pagila-data.sql:2260: invalid command \N
# psql:Data/pagila-data.sql:2261: invalid command \N
# psql:Data/pagila-data.sql:2262: invalid command \N
# psql:Data/pagila-data.sql:2263: invalid command \N
# psql:Data/pagila-data.sql:2264: invalid command \N
# psql:Data/pagila-data.sql:2265: invalid command \N
# psql:Data/pagila-data.sql:2266: invalid command \N
# psql:Data/pagila-data.sql:2267: invalid command \N
# psql:Data/pagila-data.sql:2268: invalid command \N
# psql:Data/pagila-data.sql:2269: invalid command \N
# psql:Data/pagila-data.sql:2270: invalid command \N
# psql:Data/pagila-data.sql:2271: invalid command \N
# psql:Data/pagila-data.sql:2272: invalid command \N
# psql:Data/pagila-data.sql:2273: invalid command \N
# psql:Data/pagila-data.sql:2274: invalid command \N
# psql:Data/pagila-data.sql:2275: invalid command \N
# psql:Data/pagila-data.sql:2276: invalid command \N
# psql:Data/pagila-data.sql:2277: invalid command \N
# psql:Data/pagila-data.sql:2278: invalid command \N
# psql:Data/pagila-data.sql:2279: invalid command \N
# psql:Data/pagila-data.sql:2280: invalid command \N
# psql:Data/pagila-data.sql:2281: invalid command \N
# psql:Data/pagila-data.sql:2282: invalid command \N
# psql:Data/pagila-data.sql:2283: invalid command \N
# psql:Data/pagila-data.sql:2284: invalid command \N
# psql:Data/pagila-data.sql:2285: invalid command \N
# psql:Data/pagila-data.sql:2286: invalid command \N
# psql:Data/pagila-data.sql:2287: invalid command \N
# psql:Data/pagila-data.sql:2288: invalid command \N
# psql:Data/pagila-data.sql:2289: invalid command \N
# psql:Data/pagila-data.sql:2290: invalid command \N
# psql:Data/pagila-data.sql:2291: invalid command \N
# psql:Data/pagila-data.sql:2292: invalid command \N
# psql:Data/pagila-data.sql:2293: invalid command \N
# psql:Data/pagila-data.sql:2294: invalid command \N
# psql:Data/pagila-data.sql:2295: invalid command \N
# psql:Data/pagila-data.sql:2296: invalid command \N
# psql:Data/pagila-data.sql:2297: invalid command \N
# psql:Data/pagila-data.sql:2298: invalid command \N
# psql:Data/pagila-data.sql:2299: invalid command \N
# psql:Data/pagila-data.sql:2300: invalid command \N
# psql:Data/pagila-data.sql:2301: invalid command \N
# psql:Data/pagila-data.sql:2302: invalid command \N
# psql:Data/pagila-data.sql:2303: invalid command \N
# psql:Data/pagila-data.sql:2304: invalid command \N
# psql:Data/pagila-data.sql:2305: invalid command \N
# psql:Data/pagila-data.sql:2306: invalid command \N
# psql:Data/pagila-data.sql:2307: invalid command \N
# psql:Data/pagila-data.sql:2308: invalid command \N
# psql:Data/pagila-data.sql:2309: invalid command \N
# psql:Data/pagila-data.sql:2310: invalid command \N
# psql:Data/pagila-data.sql:2311: invalid command \N
# psql:Data/pagila-data.sql:2312: invalid command \N
# psql:Data/pagila-data.sql:2313: invalid command \N
# psql:Data/pagila-data.sql:2314: invalid command \N
# psql:Data/pagila-data.sql:2315: invalid command \N
# psql:Data/pagila-data.sql:2316: invalid command \N
# psql:Data/pagila-data.sql:2317: invalid command \N
# psql:Data/pagila-data.sql:2318: invalid command \N
# psql:Data/pagila-data.sql:2319: invalid command \N
# psql:Data/pagila-data.sql:2320: invalid command \N
# psql:Data/pagila-data.sql:2321: invalid command \N
# psql:Data/pagila-data.sql:2322: invalid command \N
# psql:Data/pagila-data.sql:2323: invalid command \N
# psql:Data/pagila-data.sql:2324: invalid command \N
# psql:Data/pagila-data.sql:2325: invalid command \N
# psql:Data/pagila-data.sql:2326: invalid command \N
# psql:Data/pagila-data.sql:2327: invalid command \N
# psql:Data/pagila-data.sql:2328: invalid command \N
# psql:Data/pagila-data.sql:2329: invalid command \N
# psql:Data/pagila-data.sql:2330: invalid command \N
# psql:Data/pagila-data.sql:2331: invalid command \N
# psql:Data/pagila-data.sql:2332: invalid command \N
# psql:Data/pagila-data.sql:2333: invalid command \N
# psql:Data/pagila-data.sql:2334: invalid command \N
# psql:Data/pagila-data.sql:2335: invalid command \N
# psql:Data/pagila-data.sql:2336: invalid command \N
# psql:Data/pagila-data.sql:2337: invalid command \N
# psql:Data/pagila-data.sql:2338: invalid command \N
# psql:Data/pagila-data.sql:2339: invalid command \N
# psql:Data/pagila-data.sql:2340: invalid command \N
# psql:Data/pagila-data.sql:2341: invalid command \N
# psql:Data/pagila-data.sql:2342: invalid command \N
# psql:Data/pagila-data.sql:2343: invalid command \N
# psql:Data/pagila-data.sql:2344: invalid command \N
# psql:Data/pagila-data.sql:2345: invalid command \N
# psql:Data/pagila-data.sql:2346: invalid command \N
# psql:Data/pagila-data.sql:2347: invalid command \N
# psql:Data/pagila-data.sql:2348: invalid command \N
# psql:Data/pagila-data.sql:2349: invalid command \N
# psql:Data/pagila-data.sql:2350: invalid command \N
# psql:Data/pagila-data.sql:2351: invalid command \N
# psql:Data/pagila-data.sql:2352: invalid command \N
# psql:Data/pagila-data.sql:2353: invalid command \N
# psql:Data/pagila-data.sql:2354: invalid command \N
# psql:Data/pagila-data.sql:2355: invalid command \N
# psql:Data/pagila-data.sql:2356: invalid command \N
# psql:Data/pagila-data.sql:2357: invalid command \N
# psql:Data/pagila-data.sql:2358: invalid command \N
# psql:Data/pagila-data.sql:2359: invalid command \N
# psql:Data/pagila-data.sql:2360: invalid command \N
# psql:Data/pagila-data.sql:2361: invalid command \N
# psql:Data/pagila-data.sql:2362: invalid command \N
# psql:Data/pagila-data.sql:2363: invalid command \N
# psql:Data/pagila-data.sql:2364: invalid command \N
# psql:Data/pagila-data.sql:2365: invalid command \N
# psql:Data/pagila-data.sql:2366: invalid command \N
# psql:Data/pagila-data.sql:2367: invalid command \N
# psql:Data/pagila-data.sql:2368: invalid command \N
# psql:Data/pagila-data.sql:2369: invalid command \N
# psql:Data/pagila-data.sql:2370: invalid command \N
# psql:Data/pagila-data.sql:2371: invalid command \N
# psql:Data/pagila-data.sql:2372: invalid command \N
# psql:Data/pagila-data.sql:2373: invalid command \N
# psql:Data/pagila-data.sql:2374: invalid command \N
# psql:Data/pagila-data.sql:2375: invalid command \N
# psql:Data/pagila-data.sql:2376: invalid command \N
# psql:Data/pagila-data.sql:2377: invalid command \N
# psql:Data/pagila-data.sql:2378: invalid command \N
# psql:Data/pagila-data.sql:2379: invalid command \N
# psql:Data/pagila-data.sql:2380: invalid command \N
# psql:Data/pagila-data.sql:2381: invalid command \N
# psql:Data/pagila-data.sql:2382: invalid command \N
# psql:Data/pagila-data.sql:2383: invalid command \N
# psql:Data/pagila-data.sql:2384: invalid command \N
# psql:Data/pagila-data.sql:2385: invalid command \N
# psql:Data/pagila-data.sql:2386: invalid command \N
# psql:Data/pagila-data.sql:2387: invalid command \N
# psql:Data/pagila-data.sql:2388: invalid command \N
# psql:Data/pagila-data.sql:2389: invalid command \N
# psql:Data/pagila-data.sql:2390: invalid command \N
# psql:Data/pagila-data.sql:2391: invalid command \N
# psql:Data/pagila-data.sql:2392: invalid command \N
# psql:Data/pagila-data.sql:2393: invalid command \N
# psql:Data/pagila-data.sql:2394: invalid command \N
# psql:Data/pagila-data.sql:2395: invalid command \N
# psql:Data/pagila-data.sql:2396: invalid command \N
# psql:Data/pagila-data.sql:2397: invalid command \N
# psql:Data/pagila-data.sql:2398: invalid command \N
# psql:Data/pagila-data.sql:2399: invalid command \N
# psql:Data/pagila-data.sql:2400: invalid command \N
# psql:Data/pagila-data.sql:2401: invalid command \N
# psql:Data/pagila-data.sql:2402: invalid command \N
# psql:Data/pagila-data.sql:2403: invalid command \N
# psql:Data/pagila-data.sql:2404: invalid command \N
# psql:Data/pagila-data.sql:2405: invalid command \N
# psql:Data/pagila-data.sql:2406: invalid command \N
# psql:Data/pagila-data.sql:2407: invalid command \N
# psql:Data/pagila-data.sql:2408: invalid command \N
# psql:Data/pagila-data.sql:2409: invalid command \N
# psql:Data/pagila-data.sql:2410: invalid command \N
# psql:Data/pagila-data.sql:2411: invalid command \N
# psql:Data/pagila-data.sql:2412: invalid command \N
# psql:Data/pagila-data.sql:2413: invalid command \N
# psql:Data/pagila-data.sql:2414: invalid command \N
# psql:Data/pagila-data.sql:2415: invalid command \N
# psql:Data/pagila-data.sql:2416: invalid command \N
# psql:Data/pagila-data.sql:2417: invalid command \N
# psql:Data/pagila-data.sql:2418: invalid command \N
# psql:Data/pagila-data.sql:2419: invalid command \N
# psql:Data/pagila-data.sql:2420: invalid command \N
# psql:Data/pagila-data.sql:2421: invalid command \N
# psql:Data/pagila-data.sql:2422: invalid command \N
# psql:Data/pagila-data.sql:2423: invalid command \N
# psql:Data/pagila-data.sql:2424: invalid command \N
# psql:Data/pagila-data.sql:2425: invalid command \N
# psql:Data/pagila-data.sql:2426: invalid command \N
# psql:Data/pagila-data.sql:2427: invalid command \N
# psql:Data/pagila-data.sql:2428: invalid command \N
# psql:Data/pagila-data.sql:2429: invalid command \N
# psql:Data/pagila-data.sql:2430: invalid command \N
# psql:Data/pagila-data.sql:2431: invalid command \N
# psql:Data/pagila-data.sql:2432: invalid command \N
# psql:Data/pagila-data.sql:2433: invalid command \N
# psql:Data/pagila-data.sql:2434: invalid command \N
# psql:Data/pagila-data.sql:2435: invalid command \N
# psql:Data/pagila-data.sql:2436: invalid command \N
# psql:Data/pagila-data.sql:2437: invalid command \N
# psql:Data/pagila-data.sql:2438: invalid command \N
# psql:Data/pagila-data.sql:2439: invalid command \N
# psql:Data/pagila-data.sql:2440: invalid command \N
# psql:Data/pagila-data.sql:2441: invalid command \N
# psql:Data/pagila-data.sql:2442: invalid command \N
# psql:Data/pagila-data.sql:2443: invalid command \N
# psql:Data/pagila-data.sql:2444: invalid command \N
# psql:Data/pagila-data.sql:2445: invalid command \N
# psql:Data/pagila-data.sql:2446: invalid command \N
# psql:Data/pagila-data.sql:2447: invalid command \N
# psql:Data/pagila-data.sql:2448: invalid command \N
# psql:Data/pagila-data.sql:2449: invalid command \N
# psql:Data/pagila-data.sql:2450: invalid command \N
# psql:Data/pagila-data.sql:2451: invalid command \N
# psql:Data/pagila-data.sql:2452: invalid command \N
# psql:Data/pagila-data.sql:2453: invalid command \N
# psql:Data/pagila-data.sql:2454: invalid command \N
# psql:Data/pagila-data.sql:2455: invalid command \N
# psql:Data/pagila-data.sql:2456: invalid command \N
# psql:Data/pagila-data.sql:2457: invalid command \N
# psql:Data/pagila-data.sql:2458: invalid command \N
# psql:Data/pagila-data.sql:2459: invalid command \N
# psql:Data/pagila-data.sql:2460: invalid command \N
# psql:Data/pagila-data.sql:2461: invalid command \N
# psql:Data/pagila-data.sql:2462: invalid command \N
# psql:Data/pagila-data.sql:2463: invalid command \N
# psql:Data/pagila-data.sql:2464: invalid command \N
# psql:Data/pagila-data.sql:2465: invalid command \N
# psql:Data/pagila-data.sql:2466: invalid command \N
# psql:Data/pagila-data.sql:2467: invalid command \N
# psql:Data/pagila-data.sql:2468: invalid command \N
# psql:Data/pagila-data.sql:2469: invalid command \N
# psql:Data/pagila-data.sql:2470: invalid command \N
# psql:Data/pagila-data.sql:2471: invalid command \N
# psql:Data/pagila-data.sql:2472: invalid command \N
# psql:Data/pagila-data.sql:2473: invalid command \N
# psql:Data/pagila-data.sql:2474: invalid command \N
# psql:Data/pagila-data.sql:2475: invalid command \N
# psql:Data/pagila-data.sql:2476: invalid command \N
# psql:Data/pagila-data.sql:2477: invalid command \N
# psql:Data/pagila-data.sql:2478: invalid command \N
# psql:Data/pagila-data.sql:2479: invalid command \N
# psql:Data/pagila-data.sql:2480: invalid command \N
# psql:Data/pagila-data.sql:2481: invalid command \N
# psql:Data/pagila-data.sql:2482: invalid command \N
# psql:Data/pagila-data.sql:2483: invalid command \N
# psql:Data/pagila-data.sql:2484: invalid command \N
# psql:Data/pagila-data.sql:2485: invalid command \N
# psql:Data/pagila-data.sql:2486: invalid command \N
# psql:Data/pagila-data.sql:2487: invalid command \N
# psql:Data/pagila-data.sql:2488: invalid command \N
# psql:Data/pagila-data.sql:2489: invalid command \N
# psql:Data/pagila-data.sql:2490: invalid command \N
# psql:Data/pagila-data.sql:2491: invalid command \N
# psql:Data/pagila-data.sql:2492: invalid command \N
# psql:Data/pagila-data.sql:2493: invalid command \N
# psql:Data/pagila-data.sql:2494: invalid command \N
# psql:Data/pagila-data.sql:2495: invalid command \N
# psql:Data/pagila-data.sql:2496: invalid command \N
# psql:Data/pagila-data.sql:2497: invalid command \N
# psql:Data/pagila-data.sql:2498: invalid command \N
# psql:Data/pagila-data.sql:2499: invalid command \N
# psql:Data/pagila-data.sql:2500: invalid command \N
# psql:Data/pagila-data.sql:2501: invalid command \N
# psql:Data/pagila-data.sql:2502: invalid command \N
# psql:Data/pagila-data.sql:2503: invalid command \N
# psql:Data/pagila-data.sql:2504: invalid command \N
# psql:Data/pagila-data.sql:2505: invalid command \N
# psql:Data/pagila-data.sql:2506: invalid command \N
# psql:Data/pagila-data.sql:2507: invalid command \N
# psql:Data/pagila-data.sql:2508: invalid command \N
# psql:Data/pagila-data.sql:2509: invalid command \N
# psql:Data/pagila-data.sql:2510: invalid command \N
# psql:Data/pagila-data.sql:2511: invalid command \N
# psql:Data/pagila-data.sql:2512: invalid command \N
# psql:Data/pagila-data.sql:2513: invalid command \N
# psql:Data/pagila-data.sql:2514: invalid command \N
# psql:Data/pagila-data.sql:2515: invalid command \N
# psql:Data/pagila-data.sql:2516: invalid command \N
# psql:Data/pagila-data.sql:2517: invalid command \N
# psql:Data/pagila-data.sql:2518: invalid command \N
# psql:Data/pagila-data.sql:2519: invalid command \N
# psql:Data/pagila-data.sql:2520: invalid command \N
# psql:Data/pagila-data.sql:2521: invalid command \N
# psql:Data/pagila-data.sql:2522: invalid command \N
# psql:Data/pagila-data.sql:2523: invalid command \N
# psql:Data/pagila-data.sql:2524: invalid command \N
# psql:Data/pagila-data.sql:2525: invalid command \N
# psql:Data/pagila-data.sql:2526: invalid command \N
# psql:Data/pagila-data.sql:2527: invalid command \N
# psql:Data/pagila-data.sql:2528: invalid command \N
# psql:Data/pagila-data.sql:2529: invalid command \N
# psql:Data/pagila-data.sql:2530: invalid command \N
# psql:Data/pagila-data.sql:2531: invalid command \N
# psql:Data/pagila-data.sql:2532: invalid command \N
# psql:Data/pagila-data.sql:2533: invalid command \N
# psql:Data/pagila-data.sql:2534: invalid command \N
# psql:Data/pagila-data.sql:2535: invalid command \N
# psql:Data/pagila-data.sql:2536: invalid command \N
# psql:Data/pagila-data.sql:2537: invalid command \N
# psql:Data/pagila-data.sql:2538: invalid command \N
# psql:Data/pagila-data.sql:2539: invalid command \N
# psql:Data/pagila-data.sql:2540: invalid command \N
# psql:Data/pagila-data.sql:2541: invalid command \N
# psql:Data/pagila-data.sql:2542: invalid command \N
# psql:Data/pagila-data.sql:2543: invalid command \N
# psql:Data/pagila-data.sql:2544: invalid command \N
# psql:Data/pagila-data.sql:2545: invalid command \N
# psql:Data/pagila-data.sql:2546: invalid command \N
# psql:Data/pagila-data.sql:2547: invalid command \N
# psql:Data/pagila-data.sql:2548: invalid command \N
# psql:Data/pagila-data.sql:2549: invalid command \N
# psql:Data/pagila-data.sql:2550: invalid command \N
# psql:Data/pagila-data.sql:2551: invalid command \N
# psql:Data/pagila-data.sql:2552: invalid command \N
# psql:Data/pagila-data.sql:2553: invalid command \N
# psql:Data/pagila-data.sql:2554: invalid command \N
# psql:Data/pagila-data.sql:2555: invalid command \N
# psql:Data/pagila-data.sql:2556: invalid command \N
# psql:Data/pagila-data.sql:2557: invalid command \N
# psql:Data/pagila-data.sql:2558: invalid command \N
# psql:Data/pagila-data.sql:2559: invalid command \N
# psql:Data/pagila-data.sql:2560: invalid command \N
# psql:Data/pagila-data.sql:2561: invalid command \N
# psql:Data/pagila-data.sql:2562: invalid command \N
# psql:Data/pagila-data.sql:2563: invalid command \N
# psql:Data/pagila-data.sql:2564: invalid command \N
# psql:Data/pagila-data.sql:2565: invalid command \N
# psql:Data/pagila-data.sql:2566: invalid command \N
# psql:Data/pagila-data.sql:2567: invalid command \N
# psql:Data/pagila-data.sql:2568: invalid command \N
# psql:Data/pagila-data.sql:2569: invalid command \N
# psql:Data/pagila-data.sql:2570: invalid command \N
# psql:Data/pagila-data.sql:2571: invalid command \N
# psql:Data/pagila-data.sql:2572: invalid command \N
# psql:Data/pagila-data.sql:2573: invalid command \N
# psql:Data/pagila-data.sql:2574: invalid command \N
# psql:Data/pagila-data.sql:2575: invalid command \N
# psql:Data/pagila-data.sql:2576: invalid command \N
# psql:Data/pagila-data.sql:2577: invalid command \N
# psql:Data/pagila-data.sql:2578: invalid command \N
# psql:Data/pagila-data.sql:2579: invalid command \N
# psql:Data/pagila-data.sql:2580: invalid command \N
# psql:Data/pagila-data.sql:2581: invalid command \N
# psql:Data/pagila-data.sql:2582: invalid command \N
# psql:Data/pagila-data.sql:2583: invalid command \N
# psql:Data/pagila-data.sql:2584: invalid command \N
# psql:Data/pagila-data.sql:2585: invalid command \N
# psql:Data/pagila-data.sql:2586: invalid command \N
# psql:Data/pagila-data.sql:2587: invalid command \N
# psql:Data/pagila-data.sql:2588: invalid command \N
# psql:Data/pagila-data.sql:2589: invalid command \N
# psql:Data/pagila-data.sql:2590: invalid command \N
# psql:Data/pagila-data.sql:2591: invalid command \N
# psql:Data/pagila-data.sql:2592: invalid command \N
# psql:Data/pagila-data.sql:2593: invalid command \N
# psql:Data/pagila-data.sql:2594: invalid command \N
# psql:Data/pagila-data.sql:2595: invalid command \N
# psql:Data/pagila-data.sql:2596: invalid command \N
# psql:Data/pagila-data.sql:2597: invalid command \N
# psql:Data/pagila-data.sql:2598: invalid command \N
# psql:Data/pagila-data.sql:2599: invalid command \N
# psql:Data/pagila-data.sql:2600: invalid command \N
# psql:Data/pagila-data.sql:2601: invalid command \N
# psql:Data/pagila-data.sql:2602: invalid command \N
# psql:Data/pagila-data.sql:2603: invalid command \N
# psql:Data/pagila-data.sql:2604: invalid command \N
# psql:Data/pagila-data.sql:2605: invalid command \N
# psql:Data/pagila-data.sql:2606: invalid command \N
# psql:Data/pagila-data.sql:2607: invalid command \N
# psql:Data/pagila-data.sql:2608: invalid command \N
# psql:Data/pagila-data.sql:2609: invalid command \N
# psql:Data/pagila-data.sql:2610: invalid command \N
# psql:Data/pagila-data.sql:2611: invalid command \N
# psql:Data/pagila-data.sql:2612: invalid command \N
# psql:Data/pagila-data.sql:2613: invalid command \N
# psql:Data/pagila-data.sql:2614: invalid command \N
# psql:Data/pagila-data.sql:2615: invalid command \N
# psql:Data/pagila-data.sql:2616: invalid command \N
# psql:Data/pagila-data.sql:2617: invalid command \N
# psql:Data/pagila-data.sql:2618: invalid command \N
# psql:Data/pagila-data.sql:2619: invalid command \N
# psql:Data/pagila-data.sql:2620: invalid command \N
# psql:Data/pagila-data.sql:2621: invalid command \N
# psql:Data/pagila-data.sql:2622: invalid command \N
# psql:Data/pagila-data.sql:2623: invalid command \N
# psql:Data/pagila-data.sql:2624: invalid command \N
# psql:Data/pagila-data.sql:2625: invalid command \N
# psql:Data/pagila-data.sql:2626: invalid command \N
# psql:Data/pagila-data.sql:2627: invalid command \N
# psql:Data/pagila-data.sql:2628: invalid command \N
# psql:Data/pagila-data.sql:2629: invalid command \N
# psql:Data/pagila-data.sql:2630: invalid command \N
# psql:Data/pagila-data.sql:2631: invalid command \N
# psql:Data/pagila-data.sql:2632: invalid command \N
# psql:Data/pagila-data.sql:2633: invalid command \N
# psql:Data/pagila-data.sql:2634: invalid command \N
# psql:Data/pagila-data.sql:2635: invalid command \N
# psql:Data/pagila-data.sql:2636: invalid command \N
# psql:Data/pagila-data.sql:2637: invalid command \N
# psql:Data/pagila-data.sql:2638: invalid command \N
# psql:Data/pagila-data.sql:2639: invalid command \N
# psql:Data/pagila-data.sql:2640: invalid command \N
# psql:Data/pagila-data.sql:2641: invalid command \N
# psql:Data/pagila-data.sql:2642: invalid command \N
# psql:Data/pagila-data.sql:2643: invalid command \N
# psql:Data/pagila-data.sql:2644: invalid command \N
# psql:Data/pagila-data.sql:2645: invalid command \N
# psql:Data/pagila-data.sql:2646: invalid command \N
# psql:Data/pagila-data.sql:2647: invalid command \N
# psql:Data/pagila-data.sql:2648: invalid command \N
# psql:Data/pagila-data.sql:2649: invalid command \N
# psql:Data/pagila-data.sql:2650: invalid command \N
# psql:Data/pagila-data.sql:2651: invalid command \N
# psql:Data/pagila-data.sql:2652: invalid command \N
# psql:Data/pagila-data.sql:2653: invalid command \N
# psql:Data/pagila-data.sql:2654: invalid command \N
# psql:Data/pagila-data.sql:2655: invalid command \N
# psql:Data/pagila-data.sql:2656: invalid command \N
# psql:Data/pagila-data.sql:2657: invalid command \N
# psql:Data/pagila-data.sql:2658: invalid command \N
# psql:Data/pagila-data.sql:2659: invalid command \N
# psql:Data/pagila-data.sql:2660: invalid command \N
# psql:Data/pagila-data.sql:2661: invalid command \N
# psql:Data/pagila-data.sql:2662: invalid command \N
# psql:Data/pagila-data.sql:2663: invalid command \N
# psql:Data/pagila-data.sql:2664: invalid command \N
# psql:Data/pagila-data.sql:2665: invalid command \N
# psql:Data/pagila-data.sql:2666: invalid command \N
# psql:Data/pagila-data.sql:2667: invalid command \N
# psql:Data/pagila-data.sql:2668: invalid command \N
# psql:Data/pagila-data.sql:2669: invalid command \N
# psql:Data/pagila-data.sql:2670: invalid command \N
# psql:Data/pagila-data.sql:2671: invalid command \N
# psql:Data/pagila-data.sql:2672: invalid command \N
# psql:Data/pagila-data.sql:2673: invalid command \N
# psql:Data/pagila-data.sql:2674: invalid command \N
# psql:Data/pagila-data.sql:2675: invalid command \N
# psql:Data/pagila-data.sql:2676: invalid command \N
# psql:Data/pagila-data.sql:2677: invalid command \N
# psql:Data/pagila-data.sql:2678: invalid command \N
# psql:Data/pagila-data.sql:2679: invalid command \N
# psql:Data/pagila-data.sql:2680: invalid command \N
# psql:Data/pagila-data.sql:2681: invalid command \N
# psql:Data/pagila-data.sql:2682: invalid command \N
# psql:Data/pagila-data.sql:2683: invalid command \N
# psql:Data/pagila-data.sql:2684: invalid command \N
# psql:Data/pagila-data.sql:2685: invalid command \N
# psql:Data/pagila-data.sql:2686: invalid command \N
# psql:Data/pagila-data.sql:2687: invalid command \N
# psql:Data/pagila-data.sql:2688: invalid command \N
# psql:Data/pagila-data.sql:2689: invalid command \N
# psql:Data/pagila-data.sql:2690: invalid command \N
# psql:Data/pagila-data.sql:2691: invalid command \N
# psql:Data/pagila-data.sql:2692: invalid command \N
# psql:Data/pagila-data.sql:2693: invalid command \N
# psql:Data/pagila-data.sql:2694: invalid command \N
# psql:Data/pagila-data.sql:2695: invalid command \N
# psql:Data/pagila-data.sql:2696: invalid command \N
# psql:Data/pagila-data.sql:2697: invalid command \N
# psql:Data/pagila-data.sql:2698: invalid command \N
# psql:Data/pagila-data.sql:2699: invalid command \N
# psql:Data/pagila-data.sql:2700: invalid command \N
# psql:Data/pagila-data.sql:2701: invalid command \N
# psql:Data/pagila-data.sql:2702: invalid command \N
# psql:Data/pagila-data.sql:2703: invalid command \N
# psql:Data/pagila-data.sql:2704: invalid command \N
# psql:Data/pagila-data.sql:2705: invalid command \N
# psql:Data/pagila-data.sql:2706: invalid command \N
# psql:Data/pagila-data.sql:2707: invalid command \N
# psql:Data/pagila-data.sql:2708: invalid command \N
# psql:Data/pagila-data.sql:2709: invalid command \N
# psql:Data/pagila-data.sql:2710: invalid command \N
# psql:Data/pagila-data.sql:2711: invalid command \N
# psql:Data/pagila-data.sql:2712: invalid command \N
# psql:Data/pagila-data.sql:2713: invalid command \N
# psql:Data/pagila-data.sql:2714: invalid command \N
# psql:Data/pagila-data.sql:2715: invalid command \N
# psql:Data/pagila-data.sql:2716: invalid command \N
# psql:Data/pagila-data.sql:2717: invalid command \N
# psql:Data/pagila-data.sql:2718: invalid command \N
# psql:Data/pagila-data.sql:2719: invalid command \N
# psql:Data/pagila-data.sql:2720: invalid command \N
# psql:Data/pagila-data.sql:2721: invalid command \N
# psql:Data/pagila-data.sql:2722: invalid command \N
# psql:Data/pagila-data.sql:2723: invalid command \N
# psql:Data/pagila-data.sql:2724: invalid command \N
# psql:Data/pagila-data.sql:2725: invalid command \N
# psql:Data/pagila-data.sql:2726: invalid command \N
# psql:Data/pagila-data.sql:2727: invalid command \N
# psql:Data/pagila-data.sql:2728: invalid command \N
# psql:Data/pagila-data.sql:2729: invalid command \N
# psql:Data/pagila-data.sql:2730: invalid command \N
# psql:Data/pagila-data.sql:2731: invalid command \N
# psql:Data/pagila-data.sql:2732: invalid command \N
# psql:Data/pagila-data.sql:2733: invalid command \N
# psql:Data/pagila-data.sql:2734: invalid command \N
# psql:Data/pagila-data.sql:2735: invalid command \N
# psql:Data/pagila-data.sql:2736: invalid command \N
# psql:Data/pagila-data.sql:2737: invalid command \N
# psql:Data/pagila-data.sql:2738: invalid command \N
# psql:Data/pagila-data.sql:2739: invalid command \N
# psql:Data/pagila-data.sql:2740: invalid command \N
# psql:Data/pagila-data.sql:2741: invalid command \N
# psql:Data/pagila-data.sql:2742: invalid command \N
# psql:Data/pagila-data.sql:2743: invalid command \N
# psql:Data/pagila-data.sql:2744: invalid command \N
# psql:Data/pagila-data.sql:2745: invalid command \N
# psql:Data/pagila-data.sql:2746: invalid command \N
# psql:Data/pagila-data.sql:2747: invalid command \N
# psql:Data/pagila-data.sql:2748: invalid command \N
# psql:Data/pagila-data.sql:2749: invalid command \N
# psql:Data/pagila-data.sql:2750: invalid command \N
# psql:Data/pagila-data.sql:2751: invalid command \N
# psql:Data/pagila-data.sql:2752: invalid command \N
# psql:Data/pagila-data.sql:2753: invalid command \N
# psql:Data/pagila-data.sql:2754: invalid command \N
# psql:Data/pagila-data.sql:2755: invalid command \N
# psql:Data/pagila-data.sql:2756: invalid command \N
# psql:Data/pagila-data.sql:2757: invalid command \N
# psql:Data/pagila-data.sql:2758: invalid command \N
# psql:Data/pagila-data.sql:2759: invalid command \N
# psql:Data/pagila-data.sql:2760: invalid command \N
# psql:Data/pagila-data.sql:2761: invalid command \N
# psql:Data/pagila-data.sql:2762: invalid command \N
# psql:Data/pagila-data.sql:2763: invalid command \N
# psql:Data/pagila-data.sql:2764: invalid command \N
# psql:Data/pagila-data.sql:2765: invalid command \N
# psql:Data/pagila-data.sql:2766: invalid command \N
# psql:Data/pagila-data.sql:2767: invalid command \N
# psql:Data/pagila-data.sql:2768: invalid command \N
# psql:Data/pagila-data.sql:2769: invalid command \N
# psql:Data/pagila-data.sql:2770: invalid command \N
# psql:Data/pagila-data.sql:2771: invalid command \N
# psql:Data/pagila-data.sql:2772: invalid command \N
# psql:Data/pagila-data.sql:2773: invalid command \N
# psql:Data/pagila-data.sql:2774: invalid command \N
# psql:Data/pagila-data.sql:2775: invalid command \N
# psql:Data/pagila-data.sql:2776: invalid command \N
# psql:Data/pagila-data.sql:2777: invalid command \N
# psql:Data/pagila-data.sql:2778: invalid command \N
# psql:Data/pagila-data.sql:2779: invalid command \N
# psql:Data/pagila-data.sql:2780: invalid command \N
# psql:Data/pagila-data.sql:2781: invalid command \N
# psql:Data/pagila-data.sql:2782: invalid command \N
# psql:Data/pagila-data.sql:2783: invalid command \N
# psql:Data/pagila-data.sql:2784: invalid command \N
# psql:Data/pagila-data.sql:2785: invalid command \N
# psql:Data/pagila-data.sql:2786: invalid command \N
# psql:Data/pagila-data.sql:2787: invalid command \N
# psql:Data/pagila-data.sql:2788: invalid command \N
# psql:Data/pagila-data.sql:2789: invalid command \N
# psql:Data/pagila-data.sql:2790: invalid command \N
# psql:Data/pagila-data.sql:2791: invalid command \N
# psql:Data/pagila-data.sql:2792: invalid command \N
# psql:Data/pagila-data.sql:2793: invalid command \N
# psql:Data/pagila-data.sql:2794: invalid command \N
# psql:Data/pagila-data.sql:2795: invalid command \N
# psql:Data/pagila-data.sql:2796: invalid command \N
# psql:Data/pagila-data.sql:2797: invalid command \N
# psql:Data/pagila-data.sql:2798: invalid command \N
# psql:Data/pagila-data.sql:2799: invalid command \N
# psql:Data/pagila-data.sql:2800: invalid command \N
# psql:Data/pagila-data.sql:2801: invalid command \N
# psql:Data/pagila-data.sql:2802: invalid command \N
# psql:Data/pagila-data.sql:2803: invalid command \N
# psql:Data/pagila-data.sql:2804: invalid command \N
# psql:Data/pagila-data.sql:2805: invalid command \N
# psql:Data/pagila-data.sql:2806: invalid command \N
# psql:Data/pagila-data.sql:2807: invalid command \N
# psql:Data/pagila-data.sql:2808: invalid command \N
# psql:Data/pagila-data.sql:2809: invalid command \N
# psql:Data/pagila-data.sql:2810: invalid command \N
# psql:Data/pagila-data.sql:2811: invalid command \N
# psql:Data/pagila-data.sql:2812: invalid command \N
# psql:Data/pagila-data.sql:2813: invalid command \N
# psql:Data/pagila-data.sql:2814: invalid command \N
# psql:Data/pagila-data.sql:2815: invalid command \N
# psql:Data/pagila-data.sql:2816: invalid command \N
# psql:Data/pagila-data.sql:2817: invalid command \N
# psql:Data/pagila-data.sql:2818: invalid command \N
# psql:Data/pagila-data.sql:2819: invalid command \N
# psql:Data/pagila-data.sql:2820: invalid command \N
# psql:Data/pagila-data.sql:2821: invalid command \N
# psql:Data/pagila-data.sql:2822: invalid command \N
# psql:Data/pagila-data.sql:2823: invalid command \N
# psql:Data/pagila-data.sql:2824: invalid command \N
# psql:Data/pagila-data.sql:2825: invalid command \N
# psql:Data/pagila-data.sql:2826: invalid command \N
# psql:Data/pagila-data.sql:2827: invalid command \N
# psql:Data/pagila-data.sql:2828: invalid command \N
# psql:Data/pagila-data.sql:2829: invalid command \N
# psql:Data/pagila-data.sql:2830: invalid command \N
# psql:Data/pagila-data.sql:2831: invalid command \N
# psql:Data/pagila-data.sql:2832: invalid command \N
# psql:Data/pagila-data.sql:2833: invalid command \N
# psql:Data/pagila-data.sql:2834: invalid command \N
# psql:Data/pagila-data.sql:2835: invalid command \N
# psql:Data/pagila-data.sql:2836: invalid command \N
# psql:Data/pagila-data.sql:2837: invalid command \N
# psql:Data/pagila-data.sql:2838: invalid command \N
# psql:Data/pagila-data.sql:2839: invalid command \N
# psql:Data/pagila-data.sql:2840: invalid command \N
# psql:Data/pagila-data.sql:2841: invalid command \N
# psql:Data/pagila-data.sql:2842: invalid command \N
# psql:Data/pagila-data.sql:2843: invalid command \N
# psql:Data/pagila-data.sql:2844: invalid command \N
# psql:Data/pagila-data.sql:2845: invalid command \N
# psql:Data/pagila-data.sql:2846: invalid command \N
# psql:Data/pagila-data.sql:2847: invalid command \N
# psql:Data/pagila-data.sql:2848: invalid command \N
# psql:Data/pagila-data.sql:2849: invalid command \N
# psql:Data/pagila-data.sql:2850: invalid command \N
# psql:Data/pagila-data.sql:2851: invalid command \N
# psql:Data/pagila-data.sql:2852: invalid command \N
# psql:Data/pagila-data.sql:2853: invalid command \N
# psql:Data/pagila-data.sql:2854: invalid command \N
# psql:Data/pagila-data.sql:2855: invalid command \N
# psql:Data/pagila-data.sql:2856: invalid command \N
# psql:Data/pagila-data.sql:2857: invalid command \N
# psql:Data/pagila-data.sql:2858: invalid command \N
# psql:Data/pagila-data.sql:2859: invalid command \N
# psql:Data/pagila-data.sql:2860: invalid command \N
# psql:Data/pagila-data.sql:2861: invalid command \N
# psql:Data/pagila-data.sql:2862: invalid command \N
# psql:Data/pagila-data.sql:2863: invalid command \N
# psql:Data/pagila-data.sql:2864: invalid command \N
# psql:Data/pagila-data.sql:2865: invalid command \N
# psql:Data/pagila-data.sql:2866: invalid command \N
# psql:Data/pagila-data.sql:2867: invalid command \N
# psql:Data/pagila-data.sql:2868: invalid command \N
# psql:Data/pagila-data.sql:2869: invalid command \N
# psql:Data/pagila-data.sql:2870: invalid command \N
# psql:Data/pagila-data.sql:2871: invalid command \N
# psql:Data/pagila-data.sql:2872: invalid command \N
# psql:Data/pagila-data.sql:2873: invalid command \N
# psql:Data/pagila-data.sql:2874: invalid command \N
# psql:Data/pagila-data.sql:2875: invalid command \N
# psql:Data/pagila-data.sql:2876: invalid command \N
# psql:Data/pagila-data.sql:2877: invalid command \N
# psql:Data/pagila-data.sql:2878: invalid command \N
# psql:Data/pagila-data.sql:2879: invalid command \N
# psql:Data/pagila-data.sql:2880: invalid command \N
# psql:Data/pagila-data.sql:2881: invalid command \N
# psql:Data/pagila-data.sql:2882: invalid command \N
# psql:Data/pagila-data.sql:2883: invalid command \N
# psql:Data/pagila-data.sql:2884: invalid command \N
# psql:Data/pagila-data.sql:2885: invalid command \N
# psql:Data/pagila-data.sql:2886: invalid command \N
# psql:Data/pagila-data.sql:2887: invalid command \N
# psql:Data/pagila-data.sql:2888: invalid command \N
# psql:Data/pagila-data.sql:2889: invalid command \N
# psql:Data/pagila-data.sql:2890: invalid command \N
# psql:Data/pagila-data.sql:2891: invalid command \N
# psql:Data/pagila-data.sql:2892: invalid command \N
# psql:Data/pagila-data.sql:2893: invalid command \N
# psql:Data/pagila-data.sql:2894: invalid command \N
# psql:Data/pagila-data.sql:2895: invalid command \N
# psql:Data/pagila-data.sql:2896: invalid command \N
# psql:Data/pagila-data.sql:2897: invalid command \N
# psql:Data/pagila-data.sql:2898: invalid command \N
# psql:Data/pagila-data.sql:2899: invalid command \N
# psql:Data/pagila-data.sql:2900: invalid command \N
# psql:Data/pagila-data.sql:2901: invalid command \N
# psql:Data/pagila-data.sql:2902: invalid command \N
# psql:Data/pagila-data.sql:2903: invalid command \N
# psql:Data/pagila-data.sql:2904: invalid command \N
# psql:Data/pagila-data.sql:2905: invalid command \N
# psql:Data/pagila-data.sql:2906: invalid command \N
# psql:Data/pagila-data.sql:2907: invalid command \N
# psql:Data/pagila-data.sql:2908: invalid command \N
# psql:Data/pagila-data.sql:2909: invalid command \N
# psql:Data/pagila-data.sql:2910: invalid command \N
# psql:Data/pagila-data.sql:2911: invalid command \N
# psql:Data/pagila-data.sql:2912: invalid command \N
# psql:Data/pagila-data.sql:2913: invalid command \N
# psql:Data/pagila-data.sql:2914: invalid command \N
# psql:Data/pagila-data.sql:2915: invalid command \N
# psql:Data/pagila-data.sql:2916: invalid command \N
# psql:Data/pagila-data.sql:2917: invalid command \N
# psql:Data/pagila-data.sql:2918: invalid command \N
# psql:Data/pagila-data.sql:2919: invalid command \N
# psql:Data/pagila-data.sql:2920: invalid command \N
# psql:Data/pagila-data.sql:2921: invalid command \N
# psql:Data/pagila-data.sql:2922: invalid command \N
# psql:Data/pagila-data.sql:2923: invalid command \N
# psql:Data/pagila-data.sql:2924: invalid command \N
# psql:Data/pagila-data.sql:2925: invalid command \N
# psql:Data/pagila-data.sql:2926: invalid command \N
# psql:Data/pagila-data.sql:2927: invalid command \N
# psql:Data/pagila-data.sql:2928: invalid command \N
# psql:Data/pagila-data.sql:2929: invalid command \N
# psql:Data/pagila-data.sql:2930: invalid command \N
# psql:Data/pagila-data.sql:2931: invalid command \N
# psql:Data/pagila-data.sql:2932: invalid command \N
# psql:Data/pagila-data.sql:2933: invalid command \N
# psql:Data/pagila-data.sql:2934: invalid command \N
# psql:Data/pagila-data.sql:2935: invalid command \N
# psql:Data/pagila-data.sql:2936: invalid command \N
# psql:Data/pagila-data.sql:2937: invalid command \N
# psql:Data/pagila-data.sql:2938: invalid command \N
# psql:Data/pagila-data.sql:2939: invalid command \N
# psql:Data/pagila-data.sql:2940: invalid command \N
# psql:Data/pagila-data.sql:2941: invalid command \N
# psql:Data/pagila-data.sql:2942: invalid command \N
# psql:Data/pagila-data.sql:2943: invalid command \N
# psql:Data/pagila-data.sql:2944: invalid command \N
# psql:Data/pagila-data.sql:2945: invalid command \N
# psql:Data/pagila-data.sql:2946: invalid command \N
# psql:Data/pagila-data.sql:2947: invalid command \N
# psql:Data/pagila-data.sql:2948: invalid command \N
# psql:Data/pagila-data.sql:2949: invalid command \N
# psql:Data/pagila-data.sql:2950: invalid command \N
# psql:Data/pagila-data.sql:2951: invalid command \N
# psql:Data/pagila-data.sql:2952: invalid command \N
# psql:Data/pagila-data.sql:2953: invalid command \N
# psql:Data/pagila-data.sql:2954: invalid command \N
# psql:Data/pagila-data.sql:2955: invalid command \N
# psql:Data/pagila-data.sql:2956: invalid command \N
# psql:Data/pagila-data.sql:2957: invalid command \N
# psql:Data/pagila-data.sql:2958: invalid command \N
# psql:Data/pagila-data.sql:2959: invalid command \N
# psql:Data/pagila-data.sql:2960: invalid command \N
# psql:Data/pagila-data.sql:2961: invalid command \N
# psql:Data/pagila-data.sql:2962: invalid command \N
# psql:Data/pagila-data.sql:2963: invalid command \N
# psql:Data/pagila-data.sql:2964: invalid command \N
# psql:Data/pagila-data.sql:2965: invalid command \N
# psql:Data/pagila-data.sql:2966: invalid command \N
# psql:Data/pagila-data.sql:2967: invalid command \N
# psql:Data/pagila-data.sql:2968: invalid command \N
# psql:Data/pagila-data.sql:2969: invalid command \N
# psql:Data/pagila-data.sql:2970: invalid command \N
# psql:Data/pagila-data.sql:2971: invalid command \N
# psql:Data/pagila-data.sql:2972: invalid command \N
# psql:Data/pagila-data.sql:2973: invalid command \N
# psql:Data/pagila-data.sql:2974: invalid command \N
# psql:Data/pagila-data.sql:2975: invalid command \N
# psql:Data/pagila-data.sql:2976: invalid command \N
# psql:Data/pagila-data.sql:2977: invalid command \N
# psql:Data/pagila-data.sql:2978: invalid command \N
# psql:Data/pagila-data.sql:2979: invalid command \N
# psql:Data/pagila-data.sql:2980: invalid command \N
# psql:Data/pagila-data.sql:2981: invalid command \N
# psql:Data/pagila-data.sql:2982: invalid command \N
# psql:Data/pagila-data.sql:2983: invalid command \N
# psql:Data/pagila-data.sql:2984: invalid command \N
# psql:Data/pagila-data.sql:2985: invalid command \N
# psql:Data/pagila-data.sql:2986: invalid command \N
# psql:Data/pagila-data.sql:2987: invalid command \N
# psql:Data/pagila-data.sql:2988: invalid command \N
# psql:Data/pagila-data.sql:2989: invalid command \N
# psql:Data/pagila-data.sql:2990: invalid command \N
# psql:Data/pagila-data.sql:2991: invalid command \N
# psql:Data/pagila-data.sql:2992: invalid command \N
# psql:Data/pagila-data.sql:2993: invalid command \N
# psql:Data/pagila-data.sql:2994: invalid command \N
# psql:Data/pagila-data.sql:2995: invalid command \N
# psql:Data/pagila-data.sql:2996: invalid command \N
# psql:Data/pagila-data.sql:2997: invalid command \N
# psql:Data/pagila-data.sql:2998: invalid command \N
# psql:Data/pagila-data.sql:2999: invalid command \N
# psql:Data/pagila-data.sql:3000: invalid command \N
# psql:Data/pagila-data.sql:3001: invalid command \N
# psql:Data/pagila-data.sql:3002: invalid command \N
# psql:Data/pagila-data.sql:3003: invalid command \N
# psql:Data/pagila-data.sql:3004: invalid command \N
# psql:Data/pagila-data.sql:3005: invalid command \N
# psql:Data/pagila-data.sql:3006: invalid command \N
# psql:Data/pagila-data.sql:3007: invalid command \N
# psql:Data/pagila-data.sql:3008: invalid command \N
# psql:Data/pagila-data.sql:3009: invalid command \N
# psql:Data/pagila-data.sql:3010: invalid command \N
# psql:Data/pagila-data.sql:3011: invalid command \N
# psql:Data/pagila-data.sql:3012: invalid command \N
# psql:Data/pagila-data.sql:3013: invalid command \N
# psql:Data/pagila-data.sql:3014: invalid command \N
# psql:Data/pagila-data.sql:3015: invalid command \N
# psql:Data/pagila-data.sql:3016: invalid command \N
# psql:Data/pagila-data.sql:3017: invalid command \N
# psql:Data/pagila-data.sql:3018: invalid command \N
# psql:Data/pagila-data.sql:3019: invalid command \N
# psql:Data/pagila-data.sql:3020: invalid command \N
# psql:Data/pagila-data.sql:3021: invalid command \N
# psql:Data/pagila-data.sql:3022: invalid command \N
# psql:Data/pagila-data.sql:3023: invalid command \N
# psql:Data/pagila-data.sql:3024: invalid command \N
# psql:Data/pagila-data.sql:3025: invalid command \N
# psql:Data/pagila-data.sql:3026: invalid command \N
# psql:Data/pagila-data.sql:3027: invalid command \N
# psql:Data/pagila-data.sql:3028: invalid command \N
# psql:Data/pagila-data.sql:3029: invalid command \N
# psql:Data/pagila-data.sql:3030: invalid command \N
# psql:Data/pagila-data.sql:3031: invalid command \N
# psql:Data/pagila-data.sql:3032: invalid command \N
# psql:Data/pagila-data.sql:3033: invalid command \N
# psql:Data/pagila-data.sql:3034: invalid command \N
# psql:Data/pagila-data.sql:3035: invalid command \N
# psql:Data/pagila-data.sql:3036: invalid command \N
# psql:Data/pagila-data.sql:3037: invalid command \N
# psql:Data/pagila-data.sql:3038: invalid command \N
# psql:Data/pagila-data.sql:3039: invalid command \N
# psql:Data/pagila-data.sql:3040: invalid command \N
# psql:Data/pagila-data.sql:3041: invalid command \N
# psql:Data/pagila-data.sql:3042: invalid command \N
# psql:Data/pagila-data.sql:3043: invalid command \N
# psql:Data/pagila-data.sql:3044: invalid command \N
# psql:Data/pagila-data.sql:3045: invalid command \N
# psql:Data/pagila-data.sql:3046: invalid command \N
# psql:Data/pagila-data.sql:3047: invalid command \N
# psql:Data/pagila-data.sql:3048: invalid command \N
# psql:Data/pagila-data.sql:3049: invalid command \N
# psql:Data/pagila-data.sql:3050: invalid command \N
# psql:Data/pagila-data.sql:3051: invalid command \N
# psql:Data/pagila-data.sql:3052: invalid command \N
# psql:Data/pagila-data.sql:3053: invalid command \N
# psql:Data/pagila-data.sql:3054: invalid command \N
# psql:Data/pagila-data.sql:3055: invalid command \N
# psql:Data/pagila-data.sql:3056: invalid command \N
# psql:Data/pagila-data.sql:3057: invalid command \N
# psql:Data/pagila-data.sql:3058: invalid command \N
# psql:Data/pagila-data.sql:3059: invalid command \N
# psql:Data/pagila-data.sql:3060: invalid command \N
# psql:Data/pagila-data.sql:3061: invalid command \N
# psql:Data/pagila-data.sql:3062: invalid command \N
# psql:Data/pagila-data.sql:3063: invalid command \N
# psql:Data/pagila-data.sql:3064: invalid command \N
# psql:Data/pagila-data.sql:3065: invalid command \N
# psql:Data/pagila-data.sql:3066: invalid command \N
# psql:Data/pagila-data.sql:3067: invalid command \N
# psql:Data/pagila-data.sql:3068: invalid command \N
# psql:Data/pagila-data.sql:3069: invalid command \N
# psql:Data/pagila-data.sql:3070: invalid command \N
# psql:Data/pagila-data.sql:3071: invalid command \N
# psql:Data/pagila-data.sql:3072: invalid command \N
# psql:Data/pagila-data.sql:3073: invalid command \N
# psql:Data/pagila-data.sql:3074: invalid command \N
# psql:Data/pagila-data.sql:3075: invalid command \N
# psql:Data/pagila-data.sql:3076: invalid command \N
# psql:Data/pagila-data.sql:3077: invalid command \N
# psql:Data/pagila-data.sql:3078: invalid command \N
# psql:Data/pagila-data.sql:3079: invalid command \N
# psql:Data/pagila-data.sql:3080: invalid command \N
# psql:Data/pagila-data.sql:3081: invalid command \N
# psql:Data/pagila-data.sql:3082: invalid command \N
# psql:Data/pagila-data.sql:3083: invalid command \N
# psql:Data/pagila-data.sql:3084: invalid command \N
# psql:Data/pagila-data.sql:3085: invalid command \N
# psql:Data/pagila-data.sql:3086: invalid command \N
# psql:Data/pagila-data.sql:3087: invalid command \N
# psql:Data/pagila-data.sql:3088: invalid command \N
# psql:Data/pagila-data.sql:3089: invalid command \N
# psql:Data/pagila-data.sql:3090: invalid command \N
# psql:Data/pagila-data.sql:3091: invalid command \N
# psql:Data/pagila-data.sql:3092: invalid command \N
# psql:Data/pagila-data.sql:3093: invalid command \N
# psql:Data/pagila-data.sql:3094: invalid command \N
# psql:Data/pagila-data.sql:3095: invalid command \N
# psql:Data/pagila-data.sql:3096: invalid command \N
# psql:Data/pagila-data.sql:3097: invalid command \N
# psql:Data/pagila-data.sql:3098: invalid command \N
# psql:Data/pagila-data.sql:3099: invalid command \N
# psql:Data/pagila-data.sql:3100: invalid command \N
# psql:Data/pagila-data.sql:3101: invalid command \N
# psql:Data/pagila-data.sql:3102: invalid command \N
# psql:Data/pagila-data.sql:3103: invalid command \N
# psql:Data/pagila-data.sql:3104: invalid command \N
# psql:Data/pagila-data.sql:3105: invalid command \N
# psql:Data/pagila-data.sql:3106: invalid command \N
# psql:Data/pagila-data.sql:3107: invalid command \N
# psql:Data/pagila-data.sql:3108: invalid command \N
# psql:Data/pagila-data.sql:3109: invalid command \N
# psql:Data/pagila-data.sql:3110: invalid command \N
# psql:Data/pagila-data.sql:3111: invalid command \N
# psql:Data/pagila-data.sql:3112: invalid command \N
# psql:Data/pagila-data.sql:3113: invalid command \N
# psql:Data/pagila-data.sql:3114: invalid command \N
# psql:Data/pagila-data.sql:3115: invalid command \N
# psql:Data/pagila-data.sql:3116: invalid command \N
# psql:Data/pagila-data.sql:3117: invalid command \N
# psql:Data/pagila-data.sql:3118: invalid command \N
# psql:Data/pagila-data.sql:3119: invalid command \N
# psql:Data/pagila-data.sql:3120: invalid command \N
# psql:Data/pagila-data.sql:3121: invalid command \N
# psql:Data/pagila-data.sql:3122: invalid command \N
# psql:Data/pagila-data.sql:3123: invalid command \N
# psql:Data/pagila-data.sql:3124: invalid command \N
# psql:Data/pagila-data.sql:3125: invalid command \N
# psql:Data/pagila-data.sql:3126: invalid command \N
# psql:Data/pagila-data.sql:3127: invalid command \N
# psql:Data/pagila-data.sql:3128: invalid command \N
# psql:Data/pagila-data.sql:3129: invalid command \N
# psql:Data/pagila-data.sql:3130: invalid command \N
# ...
# psql:Data/pagila-data.sql:3169: invalid command \N
# psql:Data/pagila-data.sql:3170: invalid command \N
# psql:Data/pagila-data.sql:3171: invalid command \N
# psql:Data/pagila-data.sql:3172: invalid command \N
# psql:Data/pagila-data.sql:3173: invalid command \N
# psql:Data/pagila-data.sql:3174: invalid command \N
# psql:Data/pagila-data.sql:3175: invalid command \N
# psql:Data/pagila-data.sql:3176: invalid command \N
# psql:Data/pagila-data.sql:3177: invalid command \N
# psql:Data/pagila-data.sql:3178: invalid command \N
# psql:Data/pagila-data.sql:3179: invalid command \N
# psql:Data/pagila-data.sql:3180: invalid command \N
# psql:Data/pagila-data.sql:3181: invalid command \N
# psql:Data/pagila-data.sql:3182: invalid command \N
# psql:Data/pagila-data.sql:3183: invalid command \N
# psql:Data/pagila-data.sql:3184: invalid command \N
# psql:Data/pagila-data.sql:3185: invalid command \N
# psql:Data/pagila-data.sql:3186: invalid command \N
# psql:Data/pagila-data.sql:3187: invalid command \N
# psql:Data/pagila-data.sql:3188: invalid command \N
# psql:Data/pagila-data.sql:3189: invalid command \N
# psql:Data/pagila-data.sql:3190: invalid command \N
# psql:Data/pagila-data.sql:3191: invalid command \N
# psql:Data/pagila-data.sql:3192: invalid command \N
# psql:Data/pagila-data.sql:3193: invalid command \N
# psql:Data/pagila-data.sql:3194: invalid command \N
# psql:Data/pagila-data.sql:3195: invalid command \N
# psql:Data/pagila-data.sql:3196: invalid command \N
# psql:Data/pagila-data.sql:3197: invalid command \N
# psql:Data/pagila-data.sql:3198: invalid command \N
# psql:Data/pagila-data.sql:3199: invalid command \N
# psql:Data/pagila-data.sql:3200: invalid command \N
# psql:Data/pagila-data.sql:3201: invalid command \N
# psql:Data/pagila-data.sql:3202: invalid command \N
# psql:Data/pagila-data.sql:3203: invalid command \N
# psql:Data/pagila-data.sql:3204: invalid command \N
# psql:Data/pagila-data.sql:3205: invalid command \N
# psql:Data/pagila-data.sql:3206: invalid command \N
# psql:Data/pagila-data.sql:3207: invalid command \N
# psql:Data/pagila-data.sql:3208: invalid command \N
# psql:Data/pagila-data.sql:3209: invalid command \N
# psql:Data/pagila-data.sql:3210: invalid command \N
# psql:Data/pagila-data.sql:3211: invalid command \N
# psql:Data/pagila-data.sql:3212: invalid command \N
# psql:Data/pagila-data.sql:3213: invalid command \N
# psql:Data/pagila-data.sql:3214: invalid command \N
# psql:Data/pagila-data.sql:3215: invalid command \N
# psql:Data/pagila-data.sql:3216: invalid command \N
# psql:Data/pagila-data.sql:3217: invalid command \N
# psql:Data/pagila-data.sql:3218: invalid command \N
# psql:Data/pagila-data.sql:3219: invalid command \N
# psql:Data/pagila-data.sql:3220: invalid command \N
# psql:Data/pagila-data.sql:3221: invalid command \N
# psql:Data/pagila-data.sql:3222: invalid command \N
# psql:Data/pagila-data.sql:3223: invalid command \.
# psql:Data/pagila-data.sql:3230: ERROR:  syntax error at or near "1"
# LINE 1: 1 ACADEMY DINOSAUR A Epic Drama of a Feminist And a Mad Scie...
#         ^
# psql:Data/pagila-data.sql:8693: invalid command \.
# psql:Data/pagila-data.sql:8700: ERROR:  syntax error at or near "1"
# LINE 1: 1 1 2017-02-15 10:05:03
#         ^
# psql:Data/pagila-data.sql:9701: invalid command \.
# psql:Data/pagila-data.sql:9708: ERROR:  syntax error at or near "1"
# LINE 1: 1 6 2017-02-15 10:07:09
#         ^
# psql:Data/pagila-data.sql:14290: invalid command \.
# psql:Data/pagila-data.sql:14297: ERROR:  syntax error at or near "1"
# LINE 1: 1 1 1 2017-02-15 10:09:17
#         ^
# psql:Data/pagila-data.sql:14298: invalid command \
# psql:Data/pagila-data.sql:14299: invalid command \N
# psql:Data/pagila-data.sql:14300: invalid command \.
# psql:Data/pagila-data.sql:14307: ERROR:  syntax error at or near "1"
# LINE 1: 1 Mike Hillyer 3 Mike.Hillyer@sakilastaff.com 1 t Mike 8cb22...
#         ^
# psql:Data/pagila-data.sql:25798: invalid command \N
# psql:Data/pagila-data.sql:25843: invalid command \N
# psql:Data/pagila-data.sql:25864: invalid command \N
# psql:Data/pagila-data.sql:25866: invalid command \N
# psql:Data/pagila-data.sql:25880: invalid command \N
# psql:Data/pagila-data.sql:25896: invalid command \N
# psql:Data/pagila-data.sql:25914: invalid command \N
# psql:Data/pagila-data.sql:25949: invalid command \N
# psql:Data/pagila-data.sql:25955: invalid command \N
# psql:Data/pagila-data.sql:25960: invalid command \N
# psql:Data/pagila-data.sql:25973: invalid command \N
# psql:Data/pagila-data.sql:25976: invalid command \N
# psql:Data/pagila-data.sql:25980: invalid command \N
# psql:Data/pagila-data.sql:26013: invalid command \N
# psql:Data/pagila-data.sql:26043: invalid command \N
# psql:Data/pagila-data.sql:26058: invalid command \N
# psql:Data/pagila-data.sql:26061: invalid command \N
# psql:Data/pagila-data.sql:26086: invalid command \N
# psql:Data/pagila-data.sql:26151: invalid command \N
# psql:Data/pagila-data.sql:26152: invalid command \N
# psql:Data/pagila-data.sql:26170: invalid command \N
# psql:Data/pagila-data.sql:26213: invalid command \N
# psql:Data/pagila-data.sql:26246: invalid command \N
# psql:Data/pagila-data.sql:26299: invalid command \N
# psql:Data/pagila-data.sql:26305: invalid command \N
# psql:Data/pagila-data.sql:26313: invalid command \N
# psql:Data/pagila-data.sql:26368: invalid command \N
# psql:Data/pagila-data.sql:26370: invalid command \N
# psql:Data/pagila-data.sql:26419: invalid command \N
# psql:Data/pagila-data.sql:26430: invalid command \N
# psql:Data/pagila-data.sql:26433: invalid command \N
# psql:Data/pagila-data.sql:26444: invalid command \N
# psql:Data/pagila-data.sql:26447: invalid command \N
# psql:Data/pagila-data.sql:26525: invalid command \N
# psql:Data/pagila-data.sql:26580: invalid command \N
# psql:Data/pagila-data.sql:26655: invalid command \N
# psql:Data/pagila-data.sql:26760: invalid command \N
# psql:Data/pagila-data.sql:26792: invalid command \N
# psql:Data/pagila-data.sql:26809: invalid command \N
# psql:Data/pagila-data.sql:26827: invalid command \N
# psql:Data/pagila-data.sql:26877: invalid command \N
# psql:Data/pagila-data.sql:26913: invalid command \N
# psql:Data/pagila-data.sql:26948: invalid command \N
# psql:Data/pagila-data.sql:26968: invalid command \N
# psql:Data/pagila-data.sql:26975: invalid command \N
# psql:Data/pagila-data.sql:26985: invalid command \N
# psql:Data/pagila-data.sql:27001: invalid command \N
# psql:Data/pagila-data.sql:27019: invalid command \N
# psql:Data/pagila-data.sql:27022: invalid command \N
# psql:Data/pagila-data.sql:27039: invalid command \N
# psql:Data/pagila-data.sql:27049: invalid command \N
# psql:Data/pagila-data.sql:27062: invalid command \N
# psql:Data/pagila-data.sql:27089: invalid command \N
# psql:Data/pagila-data.sql:27095: invalid command \N
# psql:Data/pagila-data.sql:27194: invalid command \N
# psql:Data/pagila-data.sql:27200: invalid command \N
# psql:Data/pagila-data.sql:27204: invalid command \N
# psql:Data/pagila-data.sql:27205: invalid command \N
# psql:Data/pagila-data.sql:27218: invalid command \N
# psql:Data/pagila-data.sql:27241: invalid command \N
# psql:Data/pagila-data.sql:27262: invalid command \N
# psql:Data/pagila-data.sql:27273: invalid command \N
# psql:Data/pagila-data.sql:27291: invalid command \N
# psql:Data/pagila-data.sql:27311: invalid command \N
# psql:Data/pagila-data.sql:27325: invalid command \N
# psql:Data/pagila-data.sql:27328: invalid command \N
# psql:Data/pagila-data.sql:27359: invalid command \N
# psql:Data/pagila-data.sql:27382: invalid command \N
# psql:Data/pagila-data.sql:27409: invalid command \N
# psql:Data/pagila-data.sql:27411: invalid command \N
# psql:Data/pagila-data.sql:27464: invalid command \N
# psql:Data/pagila-data.sql:27481: invalid command \N
# psql:Data/pagila-data.sql:27485: invalid command \N
# psql:Data/pagila-data.sql:27512: invalid command \N
# psql:Data/pagila-data.sql:27549: invalid command \N
# psql:Data/pagila-data.sql:27564: invalid command \N
# psql:Data/pagila-data.sql:27598: invalid command \N
# psql:Data/pagila-data.sql:27601: invalid command \N
# psql:Data/pagila-data.sql:27636: invalid command \N
# psql:Data/pagila-data.sql:27654: invalid command \N
# psql:Data/pagila-data.sql:27677: invalid command \N
# psql:Data/pagila-data.sql:27693: invalid command \N
# psql:Data/pagila-data.sql:27722: invalid command \N
# psql:Data/pagila-data.sql:27724: invalid command \N
# psql:Data/pagila-data.sql:27731: invalid command \N
# psql:Data/pagila-data.sql:27767: invalid command \N
# psql:Data/pagila-data.sql:27789: invalid command \N
# psql:Data/pagila-data.sql:27837: invalid command \N
# psql:Data/pagila-data.sql:27841: invalid command \N
# psql:Data/pagila-data.sql:27864: invalid command \N
# psql:Data/pagila-data.sql:27880: invalid command \N
# psql:Data/pagila-data.sql:27881: invalid command \N
# psql:Data/pagila-data.sql:27887: invalid command \N
# psql:Data/pagila-data.sql:27890: invalid command \N
# psql:Data/pagila-data.sql:28016: invalid command \N
# psql:Data/pagila-data.sql:28055: invalid command \N
# psql:Data/pagila-data.sql:28058: invalid command \N
# psql:Data/pagila-data.sql:28082: invalid command \N
# psql:Data/pagila-data.sql:28100: invalid command \N
# psql:Data/pagila-data.sql:28200: invalid command \N
# psql:Data/pagila-data.sql:28243: invalid command \N
# psql:Data/pagila-data.sql:28254: invalid command \N
# psql:Data/pagila-data.sql:28267: invalid command \N
# psql:Data/pagila-data.sql:28270: invalid command \N
# psql:Data/pagila-data.sql:28320: invalid command \N
# psql:Data/pagila-data.sql:28362: invalid command \N
# psql:Data/pagila-data.sql:28400: invalid command \N
# psql:Data/pagila-data.sql:28409: invalid command \N
# psql:Data/pagila-data.sql:28439: invalid command \N
# psql:Data/pagila-data.sql:28462: invalid command \N
# psql:Data/pagila-data.sql:28474: invalid command \N
# psql:Data/pagila-data.sql:28477: invalid command \N
# psql:Data/pagila-data.sql:28506: invalid command \N
# psql:Data/pagila-data.sql:28518: invalid command \N
# psql:Data/pagila-data.sql:28521: invalid command \N
# psql:Data/pagila-data.sql:28522: invalid command \N
# psql:Data/pagila-data.sql:28545: invalid command \N
# psql:Data/pagila-data.sql:28569: invalid command \N
# psql:Data/pagila-data.sql:28580: invalid command \N
# psql:Data/pagila-data.sql:28620: invalid command \N
# psql:Data/pagila-data.sql:28663: invalid command \N
# psql:Data/pagila-data.sql:28676: invalid command \N
# psql:Data/pagila-data.sql:28717: invalid command \N
# psql:Data/pagila-data.sql:28727: invalid command \N
# psql:Data/pagila-data.sql:28728: invalid command \N
# psql:Data/pagila-data.sql:28790: invalid command \N
# psql:Data/pagila-data.sql:28805: invalid command \N
# psql:Data/pagila-data.sql:28818: invalid command \N
# psql:Data/pagila-data.sql:28828: invalid command \N
# psql:Data/pagila-data.sql:28833: invalid command \N
# psql:Data/pagila-data.sql:28906: invalid command \N
# psql:Data/pagila-data.sql:28908: invalid command \N
# psql:Data/pagila-data.sql:28918: invalid command \N
# psql:Data/pagila-data.sql:29036: invalid command \N
# psql:Data/pagila-data.sql:29043: invalid command \N
# psql:Data/pagila-data.sql:29062: invalid command \N
# psql:Data/pagila-data.sql:29071: invalid command \N
# psql:Data/pagila-data.sql:29180: invalid command \N
# psql:Data/pagila-data.sql:29217: invalid command \N
# psql:Data/pagila-data.sql:29230: invalid command \N
# psql:Data/pagila-data.sql:29235: invalid command \N
# psql:Data/pagila-data.sql:29256: invalid command \N
# psql:Data/pagila-data.sql:29323: invalid command \N
# psql:Data/pagila-data.sql:29396: invalid command \N
# psql:Data/pagila-data.sql:29469: invalid command \N
# psql:Data/pagila-data.sql:29493: invalid command \N
# psql:Data/pagila-data.sql:29536: invalid command \N
# psql:Data/pagila-data.sql:29584: invalid command \N
# psql:Data/pagila-data.sql:29595: invalid command \N
# psql:Data/pagila-data.sql:29596: invalid command \N
# psql:Data/pagila-data.sql:29599: invalid command \N
# psql:Data/pagila-data.sql:29616: invalid command \N
# psql:Data/pagila-data.sql:29628: invalid command \N
# psql:Data/pagila-data.sql:29673: invalid command \N
# psql:Data/pagila-data.sql:29709: invalid command \N
# psql:Data/pagila-data.sql:29725: invalid command \N
# psql:Data/pagila-data.sql:29732: invalid command \N
# psql:Data/pagila-data.sql:29743: invalid command \N
# psql:Data/pagila-data.sql:29756: invalid command \N
# psql:Data/pagila-data.sql:29760: invalid command \N
# psql:Data/pagila-data.sql:29799: invalid command \N
# psql:Data/pagila-data.sql:29834: invalid command \N
# psql:Data/pagila-data.sql:29844: invalid command \N
# psql:Data/pagila-data.sql:29879: invalid command \N
# psql:Data/pagila-data.sql:29945: invalid command \N
# psql:Data/pagila-data.sql:29946: invalid command \N
# psql:Data/pagila-data.sql:29956: invalid command \N
# psql:Data/pagila-data.sql:29996: invalid command \N
# psql:Data/pagila-data.sql:30011: invalid command \N
# psql:Data/pagila-data.sql:30015: invalid command \N
# psql:Data/pagila-data.sql:30018: invalid command \N
# psql:Data/pagila-data.sql:30030: invalid command \N
# psql:Data/pagila-data.sql:30036: invalid command \N
# psql:Data/pagila-data.sql:30046: invalid command \N
# psql:Data/pagila-data.sql:30079: invalid command \N
# psql:Data/pagila-data.sql:30081: invalid command \N
# psql:Data/pagila-data.sql:30095: invalid command \N
# psql:Data/pagila-data.sql:30114: invalid command \N
# psql:Data/pagila-data.sql:30163: invalid command \N
# psql:Data/pagila-data.sql:30168: invalid command \N
# psql:Data/pagila-data.sql:30176: invalid command \N
# psql:Data/pagila-data.sql:30195: invalid command \N
# psql:Data/pagila-data.sql:30267: invalid command \N
# psql:Data/pagila-data.sql:30352: invalid command \.
# psql:Data/pagila-data.sql:30359: ERROR:  syntax error at or near "2"
# LINE 1: 2 2005-05-24 22:54:33 1525 459 2005-05-28 19:40:33 1 2017-02...
#         ^
# psql:Data/pagila-data.sql:46409: invalid command \.
# psql:Data/pagila-data.sql:46416: ERROR:  syntax error at or near "16050"
# LINE 1: 16050 269 2 7 1.99 2017-01-24 21:40:19.996577
#         ^
# psql:Data/pagila-data.sql:46423: ERROR:  relation "address_address_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('address_address_id_seq', 605, true...
#                                  ^
# psql:Data/pagila-data.sql:46430: ERROR:  relation "category_category_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('category_category_id_seq', 16, tru...
#                                  ^
# psql:Data/pagila-data.sql:46437: ERROR:  relation "city_city_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('city_city_id_seq', 600, true);
#                                  ^
# psql:Data/pagila-data.sql:46444: ERROR:  relation "country_country_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('country_country_id_seq', 109, true...
#                                  ^
# psql:Data/pagila-data.sql:46451: ERROR:  relation "customer_customer_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('customer_customer_id_seq', 599, tr...
#                                  ^
# psql:Data/pagila-data.sql:46458: ERROR:  relation "film_film_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('film_film_id_seq', 1000, true);
#                                  ^
# psql:Data/pagila-data.sql:46465: ERROR:  relation "inventory_inventory_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('inventory_inventory_id_seq', 4581,...
#                                  ^
# psql:Data/pagila-data.sql:46472: ERROR:  relation "language_language_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('language_language_id_seq', 6, true...
#                                  ^
# psql:Data/pagila-data.sql:46479: ERROR:  relation "payment_payment_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('payment_payment_id_seq', 32098, tr...
#                                  ^
# psql:Data/pagila-data.sql:46486: ERROR:  relation "rental_rental_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('rental_rental_id_seq', 16049, true...
#                                  ^
# psql:Data/pagila-data.sql:46493: ERROR:  relation "staff_staff_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('staff_staff_id_seq', 2, true);
#                                  ^
# psql:Data/pagila-data.sql:46500: ERROR:  relation "store_store_id_seq" does not exist
# LINE 1: SELECT pg_catalog.setval('store_store_id_seq', 2, true);
#                                  ^

# %%
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ## 6.1 Facts Table has all the needed dimensions, no need for deep joins

# %%
# %%time
# %%sql
SELECT movie_key, date_key, customer_key, sales_amount
FROM factSales 
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# (psycopg2.ProgrammingError) relation "factsales" does not exist
# LINE 2: FROM factSales
#              ^
#  [SQL: 'SELECT movie_key, date_key, customer_key, sales_amount\nFROM factSales \nlimit 5;']
# CPU times: user 0 ns, sys: 3.19 ms, total: 3.19 ms
# Wall time: 4.86 ms

# %% [markdown]
# ## 6.2 Join fact table with dimensions to replace keys with attributes
#
# As you run each cell, pay attention to the time that is printed. Which schema do you think will run faster?
#
# ##### Star Schema

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
FROM factSales 
JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
group by (dimMovie.title, dimDate.month, dimCustomer.city)
order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc;

# %% [markdown]
# ##### 3NF Schema

# %%
# %%time
# %%sql
SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue
FROM payment p
JOIN rental r    ON ( p.rental_id = r.rental_id )
JOIN inventory i ON ( r.inventory_id = i.inventory_id )
JOIN film f ON ( i.film_id = f.film_id)
JOIN customer c  ON ( p.customer_id = c.customer_id )
JOIN address a ON ( c.address_id = a.address_id )
JOIN city ci ON ( a.city_id = ci.city_id )
group by (f.title, month, ci.city)
order by f.title, month, ci.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# (psycopg2.ProgrammingError) relation "payment" does not exist
# LINE 2: FROM payment p
#              ^
#  [SQL: 'SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue\nFROM payment p\nJOIN rental r    ON ( p.rental_id = r.rental_id )\nJOIN inventory i ON ( r.inventory_id = i.inventory_id )\nJOIN film f ON ( i.film_id = f.film_id)\nJOIN customer c  ON ( p.customer_id = c.customer_id )\nJOIN address a ON ( c.address_id = a.address_id )\nJOIN city ci ON ( a.city_id = ci.city_id )\ngroup by (f.title, month, ci.city)\norder by f.title, month, ci.city, revenue desc;']
# CPU times: user 6.91 ms, sys: 0 ns, total: 6.91 ms
# Wall time: 9.05 ms

# %% [markdown]
# # Conclusion

# %% [markdown]
# We were able to show that:
# * The star schema is easier to understand and write queries against.
# * Queries with a star schema are more performant.
